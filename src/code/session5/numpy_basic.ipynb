# %%
class StudentInfo:
    name = "sara"
    age = 20

    def std_info(self):
        print("my name is sara")

# %%
s1=StudentInfo()
s1.name = "sara"
s1.age = 20
s1.name
s1.std_info()
s2=StudentInfo()
# Out:
# my name is sara

# %%
s1 = StudentInfo()
s1.std_info()
# Out:
# my name is sara

# %%
class StudentInfo:
    name = "sara"
    age = 20

    def std_info(self):
        print(self)

# %%
s1 = StudentInfo()
print(s1)
print(s1.std_info())
# Out:
# <__main__.StudentInfo object at 0x000002370F88BC50>
# <__main__.StudentInfo object at 0x000002370F88BC50>
# None

# %%
class Student:

    def __init__(self, name:str = "test", age:int = 20) -> None:
        self.name = name
        self.age = age
        self.grade = 100

    def get_info(self):
        return f"my name is {self.name} and my age is {self.age}"

# %%
s1 = Student()
s1.name
s1.age
s1.get_info()
# Out:
# 'my name is test and my age is 20'

# %%
from abc import ABC ,abstractmethod
class Animal(ABC):
    def move(self):
        pass
class Bird(Animal):
    def move(self):
        print("move from bird")
class Cat(Animal):
    def move(self):
        print("move from cat")
a=Bird()
a.move()
# Out:
# move from bird

# %%
from abc import ABC ,abstractmethod
class Animal(ABC):
    @abstractmethod

    def move(self):
        pass

class Bird(Animal):
    def move(self):
a=Bird()
a.move()
# Out:
#   Cell In[18], line 10
#     a=Bird()
#             ^
# IndentationError: expected an indented block after function definition on line 9

# %%
class Rectangle:
    length = 5
    width = 10

    def area(self):
        return self.length * self.width
r = Rectangle()
print(r.length)
print(r.width)
print(r.area())
# Out:
# 5
# 10
# 50

# %%
class Rectangle:
    __length = 5
    width = 10

    def area(self):
        return self.__length * self.width
r = Rectangle()
print(r._Rectangle__length)
print(r.width)
print(r.area())
print(r.__dict__)
# Out:
# 5
# 10
# 50
# {}

# %%
class parent:
    def __init__(self) -> None:
        self.__value = 10


class child(parent):
    def __init__(self) -> None:
        super().__init__()
        self.__value = 28

# %%
c = child()
print(c.__dict__)
# Out:
# {'_parent__value': 10, '_child__value': 28}

# %%
class shape:
    def calculate_area(self):
        pass

class circle(shape):
    def __init__(self, radius) -> None:
        self.radius = radius

    def calculate_area(self):
        return 3.14 * (self.radius ** 2)

class square(shape):
    def __init__(self, side) -> None:
        self.side = side

    def calculate_area(self):
        return self.side ** 2

x=circle(5)
y=square(4)
print("Area: ",x.calculate_area())
print("Area: ",y.calculate_area())
# Out:
# Area:  78.5
# Area:  16

# %%
class Model:
    def pridect(self , x):
        raise NotADirectoryError

class LinearRegression(Model):
    def pridect(self, x):
        return "Linear Regression Prediction"
class DecisionTree (Model):
    def pridect (self, x):
        return "DecisionTree Predicion"

models = [LinearRegression(),DecisionTree()]
for model in models :
    print (model.pridect(None))
# Out:
# Linear Regression Prediction
# DecisionTree Predicion

# %%
clac(int)
clac (int, int)
clac (int, int, int)

# %%
class calculator:
    def add(self, a):
        return a
    
    def add(self, a, b=10):
        return a + b

# %%
c1 = calculator()
c1.add(10)
# Out:
# 20

# %%
class Student:
    def __init__(self, name ,  age ):
        self._name = name
        self._age = age
    @property
    def name(self):
        return self._name

# %%
s1= Student("sara",20)
s1.name
# Out:
# 'sara'
