# %%
import numpy as np

# %%
vec = np.array([1, 2, 3, 4, 5, 6])
mat = vec

# %%
def n_init(shape,value=0):
    return np.full(shape, value)

# %%
n_init((3,3))
# Out:
# array([[0, 0, 0],
#        [0, 0, 0],
#        [0, 0, 0]])
