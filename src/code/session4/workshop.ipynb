# %%
x=10

# %%
def factorial(num:int)-> int:
    '''
    calaculates n! using recursion
    Args:
         num(int): user input the int number
         returns:
                 num(int):returns the factorial of the number
    '''
    if num ==0 :
        return 1
    return num * factorial(num-1)

# %%
factorial(5)
# Out:
# 120

# %%
def is_prime(num:int) -> bool:
    '''
    check for the number is prime or not
    Args:
         num(int): number for check
             returns:
                    bool: true if that prime or false if that not prime
    '''
    if num < 2:
        return False
    for i in range(2,num):
        if num % i == 0:
            return False
    return True

# %%
is_prime(7)
# Out:
# True

# %%
is_prime(10)
# Out:
# False

# %%
def common_divisor(num1:int,num2:int)-> list[int]:
    '''
    this function help to calc the common division
    '''
    limit = min(num1,num2)
    divisors = []

    for divisor in range(1,limit+1):
        if num1 % divisor == 0 and num2 % divisor == 0:
            divisors.append(divisor)
    return divisors

# %%
common_divisor(10,20)
# Out:
# [1, 2, 5, 10]

# %%
from math_basic import factorial, is_prime, common_divisor

# %%
s = "Hello Depi"
lst = s.split()
print(lst)
new_lst = lst[::-1]
print(new_lst)
# Out:
# ['Hello', 'Depi']
# ['Depi', 'Hello']

# %%
def reverse_text(s: str) -> list[str]:
    '''
    Reverses the order of words in a string.
    '''
    if not isinstance(s, str):
        raise TypeError("text must be a string")
    lst = s.split()
    print(lst)
    new_list = lst[::-1]
    return new_list

# %%
user_input = input("Enter a string: ")
reverse_text(user_input)
# Out:
# ['444']
# ['444']

# %%
reverse_text(44)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 reverse_text(44)
#
# Cell In[18], line 6, in reverse_text(s)
#       2     '''
#       3     Reverses the order of words in a string.
#       4     '''
#       5     if not isinstance(s, str):
# ----> 6         raise TypeError("text must be a string")
#       7     lst = s.split()
#       8     print(lst)
#       9     new_list = lst[::-1]
#
# TypeError: text must be a string

# %%
def reverse_text(s: str) -> str:
    return " ".join(s.split()[::-1])

# %%
reverse_text("hi depi")
# Out:
# 'depi hi'

# %%
import random
character = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
password = ""
for _ in range(8):
    password += random.choice(character)
password
# Out:
# 'JKrUY79X'

# %%
import random
import string
import secrets
def generate_pass(length):
    character = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password = ""
    for _ in range(length):
        password += random.choice(character)
    return password

# %%
import string

character = (string.ascii_letters +  
                 string.digits + 
                 string.punctuation)
character
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
generate_pass(12)
# Out:
# 'M$3uWw(a$,Sp'

# %%
import random
import string
import secrets
def generate_pass(length: int) -> str:

    character = (string.ascii_letters +  
                 string.digits + 
                 string.punctuation)
    password = ""
    return "".join(secrets.choice(character) for _ in range(length) )

# %%
generate_pass(12)
# Out:
# 'LZnH(O*#~>^j'

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
set1 = {1,1,1,2,2,3,3,3}
set1
# Out:
# {1, 2, 3}

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
counts = {word: 0 for word in unique_words}
counts
# Out:
# {'No': 0, 'Hi': 0, 'Ali': 0, 'Welcome': 0}

# %%
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
unique_words = set(words)
counts = {word: 0 for word in unique_words}
for i in unique_words:
    for  j in words:
         if i== j :
              counts[i] += 1
counts
# Out:
# {'Welcome': 1, 'Ali': 4, 'No': 3, 'Hi': 2}

# %%
# Predefined responses
import random
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

# %%
get_response("hello")
# Out:
# 'Hello!'

# %%
import random
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

def main_bot():
    print("chatbot: Hi How can assist you?")

    while True:
        user_input = input("user: ").lower()
        response = get_response(user_input)
        print("chatbot:", response)

        if user_input == "goodbye":
            break

# %%
main_bot()
# Out:
# chatbot: Hi How can assist you?
# chatbot: Hello!
# chatbot: Could you please rephrase that?
# chatbot: Goodbye!

# %%
import random
import json

with open("D:\\saroo\\DEPI-R5-AI\\ai_diploma_master\\src\\code\\session4\\chatbot\\data.json", "r") as file:
    responses = json.load(file)
